# %%
import pandas as pd
import matplotlib as plt
from soccerplots.radar_chart import Radar

# %%
#read chelsea dataset
df = pd.read_csv(r"C:\Users\Jonny\chelseaplayers.csv")
df
#shows first instances
# Out:
#                  Player Positon  Apps   Min  Goals  Assists  sh90    xG    xA  \
# 0           Mason Mount       M    19  1253      7        5  2.80  5.08  4.18
# 1              Jorginho       M    18  1373      6        1  0.79  5.06  2.09
# 2         Romelu Lukaku       F    14   907      5        0  2.28  4.54  2.22
# 3           Reece James       D    16  1114      4        5  1.70  1.88  3.71
# 4          Ben Chilwell       D     6   540      3        1  2.17  1.30  0.83
# 5     Christian Pulisic       F    12   748      3        0  1.44  3.27  0.42
# 6          N'Golo Kante       M    13   860      2        1  0.84  0.85  1.02
# 7       Antonio Rudiger       D    21  1890      2        0  1.29  1.69  0.65
# 8          Thiago Silva       D    18  1451      2        0  0.62  0.77  0.18
# 9           Kai Havertz       F    15   953      2        1  2.55  3.86  1.21
# 10      Trevoh Chalobah       D    14   919      2        0  0.39  0.61  0.05
# 11          Timo Werner       F    10   564      1        1  3.03  2.65  0.09
# 12        Marcos Alonso       D    16  1352      1        2  1.40  1.58  2.88
# 13    Calum Hudson-Odoi       F    13   791      1        1  1.71  2.34  2.50
# 14         Hakim Ziyech       F    11   618      1        2  4.08  2.22  2.05
# 15  Andreas Christensen       D    13  1001      0        0  0.27  0.55  0.12
# 16         Ross Barkley       M     5   145      0        0  3.72  0.77  0.58
# 17    Cesar Azpilicueta       D    15  1223      0        2  0.44  0.74  1.75
# 18   Ruben Loftus Cheek       M    12   668      0        2  1.83  0.76  1.35
# 19          Saul Niguez       M     5   165      0        0  0.55  0.06  0.00
#
#     xG90  xA90
# 0   0.36  0.30
# 1   0.33  0.14
# 2   0.45  0.22
# 3   0.15  0.30
# 4   0.22  0.14
# 5   0.39  0.05
# 6   0.09  0.11
# 7   0.08  0.03
# 8   0.05  0.01
# 9   0.36  0.11
# 10  0.06  0.00
# 11  0.42  0.01
# 12  0.10  0.19
# 13  0.27  0.28
# 14  0.32  0.30
# 15  0.05  0.01
# 16  0.48  0.36
# 17  0.05  0.13
# 18  0.10  0.18
# 19  0.03  0.00

# %%
#comparison
df= df[ (df['Player']=='Ben Chilwell')|(df['Player']=='Reece James')].reset_index()
df
# Out:
#    index        Player Positon  Apps   Min  Goals  Assists  sh90    xG    xA  \
# 0      3   Reece James       D    16  1114      4        5  1.70  1.88  3.71
# 1      4  Ben Chilwell       D     6   540      3        1  2.17  1.30  0.83
#
#    xG90  xA90
# 0  0.15  0.30
# 1  0.22  0.14

# %%
df = df.drop(['index','Positon'],axis=1)
df
# Out:
#          Player  Apps   Min  Goals  Assists  sh90    xG    xA  xG90  xA90
# 0   Reece James    16  1114      4        5  1.70  1.88  3.71  0.15  0.30
# 1  Ben Chilwell     6   540      3        1  2.17  1.30  0.83  0.22  0.14

# %%
#Use Paramaters
params= list(df.columns)
params=params[1:]
params
# Out:
# ['Apps', 'Min', 'Goals', 'Assists', 'sh90', 'xG', 'xA', 'xG90', 'xA90']

# %%
#Use lists with ranges for data
ranges = []
a_values = []
b_values = []
for x in params:
    a = min(df[params][x])
    a = a -(a*.25)

    b = max(df[params][x])
    b = b +(b*.25)
    ranges.append((a,b))

for x in range(len(df['Player'])):
    if df['Player'][x]=='Ben Chilwell':
        a_values = df.iloc[x].values.tolist()
    if df['Player'][x]=='Reece James':
        b_values = df.iloc[x].values.tolist()

a_values = a_values[1:]
b_values = b_values[1:]

values = [a_values,b_values]

# %%
#add title
title = dict(
    title_name= 'Ben Chilwell',
    title_colour='blue',
    subtitle_name = 'Chelsea',
    subtitle_colour = 'blue',
    title_name_2= 'Reece James',
    title_colour_2='yellow',
    subtitle_name_2 = 'Chelsea',
    subtitle_colour_2 = 'yellow',
    title_fontsize = 18,
    subtitle_fontsize =15
)
endnote = 'Jonathan Crawford'

# %%
radar = Radar()

fig,ax = radar.plot_radar(ranges=ranges,params=params,values=values,
                    radar_color=['red','yellow'],
                    alphas=[.75,.6],title=title,endnote=endnote,
                    compare=True)
# Out:
# findfont: Font family ['Liberation Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Liberation Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Liberation Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Liberation Serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Liberation Serif'] not found. Falling back to DejaVu Sans.
