# %%
import pandas as pd
import matplotlib as plt
from soccerplots.radar_chart import Radar

# %%
#read chelsea dataset
df = pd.read_csv(r"C:\Users\Jonny\league.csv")
df
#shows first instances
# Out:
#               Team  Games Played  Goal Difference    xG   xGA  Net xG  \
# 0         Man City            22               41  47.2  13.7    33.5
# 1        Liverpool            21               37  54.5  19.5    35.0
# 2          Chelsea            22               28  40.9  21.7    19.2
# 3         West Ham            22               11  35.7  28.6     7.1
# 4       Man United            20                3  28.8  27.5     1.3
# 5          Arsenal            20                8  26.6  27.7    -1.1
# 6         Brighton            20                0  26.5  23.0     3.5
# 7        Brentford            21               -9  27.0  25.5     1.5
# 8           Wolves            20                2  22.0  24.0    -2.0
# 9      Southampton            21               -8  27.3  31.5    -4.2
# 10  Crystal Palace            21               -1  25.1  26.5    -1.4
# 11       Tottenham            18                3  23.9  22.4     1.5
# 12         Everton            19              -10  23.7  30.0    -6.3
# 13     Aston Villa            20               -5  20.2  26.6    -6.4
# 14           Leeds            20              -15  24.1  34.5   -10.4
# 15         Watford            19              -14  21.8  34.2   -12.4
# 16       Leicester            18               -2  25.3  33.4    -8.1
# 17         Burnley            17              -11  17.4  27.8   -10.4
# 18         Norwich            21              -35  15.2  36.3   -21.1
# 19       Newcastle            20              -23  18.1  36.9   -18.8
#
#     xG Points  Points
# 0          62      56
# 1          51      45
# 2          44      43
# 3          40      37
# 4          36      32
# 5          35      35
# 6          29      28
# 7          29      23
# 8          26      31
# 9          25      24
# 10         24      24
# 11         23      33
# 12         23      19
# 13         22      23
# 14         17      22
# 15         16      14
# 16         15      25
# 17         12      11
# 18         11      13
# 19         10      12

# %%
#comparison
df= df[ (df['Team']=='Man City')|(df['Team']=='Liverpool')].reset_index()
df
# Out:
#    index       Team  Games Played  Goal Difference    xG   xGA  Net xG  \
# 0      0   Man City            22               41  47.2  13.7    33.5
# 1      1  Liverpool            21               37  54.5  19.5    35.0
#
#    xG Points  Points
# 0         62      56
# 1         51      45

# %%
df = df.drop(['index'],axis=1)
df
# Out:
#         Team  Games Played  Goal Difference    xG   xGA  Net xG  xG Points  \
# 0   Man City            22               41  47.2  13.7    33.5         62
# 1  Liverpool            21               37  54.5  19.5    35.0         51
#
#    Points
# 0      56
# 1      45

# %%
#Use Paramaters
params= list(df.columns)
params=params[1:]
params
# Out:
# ['Games Played',
#  'Goal Difference',
#  'xG',
#  'xGA',
#  'Net xG',
#  'xG Points',
#  'Points']

# %%
#Use lists with ranges for data
ranges = []
a_values = []
b_values = []
for x in params:
    a = min(df[params][x])
    a = a -(a*.25)

    b = max(df[params][x])
    b = b +(b*.25)
    ranges.append((a,b))

for x in range(len(df['Team'])):
    if df['Team'][x]=='Man City':
        a_values = df.iloc[x].values.tolist()
    if df['Team'][x]=='Liverpool':
        b_values = df.iloc[x].values.tolist()

a_values = a_values[1:]
b_values = b_values[1:]

values = [a_values,b_values]

# %%
#add title
title = dict(
    title_name= 'Man City',
    title_colour='blue',
    subtitle_name = 'Man City',
    subtitle_colour = 'blue',
    title_name_2= 'Liverpool',
    title_colour_2='yellow',
    subtitle_name_2 = 'Liverpool',
    subtitle_colour_2 = 'yellow',
    title_fontsize = 18,
    subtitle_fontsize =15
)
endnote = 'Jonathan Crawford'

# %%
radar = Radar()

fig,ax = radar.plot_radar(ranges=ranges,params=params,values=values,
                    radar_color=['blue','red'],
                    alphas=[.75,.6],title=title,endnote=endnote,
                    compare=True)
